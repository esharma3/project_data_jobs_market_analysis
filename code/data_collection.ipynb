# %% [markdown]
# ## Data Jobs Market Analysis for Top 10 US Tech(IT) Cities
#
#
# ** This module is for data collection. **
#
# _Data Sources Used in this module:_
#     1. Indeed API
#     2. Web scraping

# %%
# importing dependencies 

import pandas as pd
from indeed import IndeedClient
from config import publisher_key
import requests
import bs4
import re
from html.parser import HTMLParser

# %% [markdown]
# ### Extracting Data Related Jobs using API for top 10 US Tech(IT) Cities

# %%
# function to get the total count of all 'data' related jobs posted on Indeed.com in last 120 days (using Indeed API)

def get_job_count(key, start, location):

    client = IndeedClient(publisher = key)
    
    parameters = {'q' : "title:('data' OR ('business' AND 'intelligence') OR 'BI' OR \
                  ('machine' AND 'learning') OR 'AI' OR ('artificial' AND 'intelligence') \
                  OR 'tableau' OR ('power' AND 'BI') OR statistical' OR 'statistician)",
                  'l' : location,                  
                  'sort' : "date",
                  'fromage' : "119",
                  'toage' : "0",
                  'limit' : "25",
                  'radius': 25, 
                  'userip' : "192.168.0.58",
                  'useragent' : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6)",
                  'start': start
                 }
    
    search_results = client.search(**parameters)
    jobs_count = search_results['totalResults']
    return jobs_count

# %%
# function to get the details of all 'data' related jobs posted on Indeed.com in last 120 days (using Indeed API)

def get_job_data(key, start, location):
    
    client = IndeedClient(publisher = key)
    
    parameters = {'q' : "title:('data' OR ('business' AND 'intelligence') OR 'BI' OR \
                  ('machine' AND 'learning') OR 'AI' OR ('artificial' AND 'intelligence') \
                  OR 'tableau' OR ('power' AND 'BI') OR statistical' OR 'statistician)",
                  'l' : location,
                  'sort' : "date",
                  'fromage' : "119",
                  'toage' : "0",
                  'limit' : "25",
                  'radius': 25,
                  'userip' : "192.168.0.58",
                  'useragent' : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6)",
                  'start': start
                 }
    
    search_results = client.search(**parameters)
    jobs_df = pd.DataFrame(search_results['results'])
    return jobs_df

# %%
# defining a list of cities(locations) to be used for analysis

cities = ['Austin, TX', 'San Francisco, CA', 'Raleigh, NC', 
          'Denver, CO', 'Seattle, WA', 'Atlanta, GA', 
          'Boston, MA', 'New York, NY', 'Washington, DC', 'Columbus, OH']

# %%
# calling the function to find the total number of 'data' related jobs posted on Indeed.com in last 120 days for 10 cities

total_job_count = 0
city_job_count = 0

for city in cities:
    
    city_job_count = get_job_count(key=publisher_key, start=0, location=city)
    print(f'Total number of data jobs posted for {city} in last 120 days -', city_job_count)
    total_job_count +=  city_job_count

print('Total number of data job posted on Indeed.com in last 120 days for selected list of cities is: ', total_job_count)
# Out:
# Total number of data jobs posted for Austin, TX in last 120 days - 457
# Total number of data jobs posted for San Francisco, CA in last 120 days - 1368
# Total number of data jobs posted for Raleigh, NC in last 120 days - 424
# Total number of data jobs posted for Denver, CO in last 120 days - 563
# Total number of data jobs posted for Seattle, WA in last 120 days - 1065
# Total number of data jobs posted for Atlanta, GA in last 120 days - 641
# Total number of data jobs posted for Boston, MA in last 120 days - 1249
# Total number of data jobs posted for New York, NY in last 120 days - 1777
# Total number of data jobs posted for Washington, DC in last 120 days - 2378
# Total number of data jobs posted for Columbus, OH in last 120 days - 299
# Total number of data job posted on Indeed.com in last 120 days for selected list of cities is:  10221

# %%
# calling function to get the details of all 'data' related jobs posted on Indeed.com in last 120 days for 10 cities
# storing it in a dataframe

data_jobs_df = pd.DataFrame()

try:
    for city in cities:

        start = 0
        count = 0
        city_job_count = get_job_count(key=publisher_key, start=0, location=city)
        # below print statement is for the purpose of ensuring the loop is processing all pages  
        print(f'Total number of data jobs posted for {city} in last 120 days -', city_job_count)
        count = (city_job_count // 25) + 1  

        for i in range(0, count):
            print(i, '-', start)
            data_jobs = get_job_data(key=publisher_key, start=start, location=city)
            data_jobs_df = data_jobs_df.append(data_jobs, ignore_index=True)
            start += 25
            
except Exception:
    pass
# Out:
# Total number of data jobs posted for Austin, TX in last 120 days - 457
# 0 - 0
# 1 - 25
# 2 - 50
# 3 - 75
# 4 - 100
# 5 - 125
# 6 - 150
# 7 - 175
# 8 - 200
# 9 - 225
# 10 - 250
# 11 - 275
# 12 - 300
# 13 - 325
# 14 - 350
# 15 - 375
# 16 - 400
# 17 - 425
# 18 - 450
# Total number of data jobs posted for San Francisco, CA in last 120 days - 1368
# 0 - 0
# 1 - 25
# 2 - 50
# 3 - 75
# 4 - 100
# 5 - 125
# 6 - 150
# 7 - 175
# 8 - 200
# 9 - 225
# 10 - 250
# 11 - 275
# 12 - 300
# 13 - 325
# 14 - 350
# 15 - 375
# 16 - 400
# 17 - 425
# 18 - 450
# 19 - 475
# 20 - 500
# 21 - 525
# 22 - 550
# 23 - 575
# 24 - 600
# 25 - 625
# 26 - 650
# 27 - 675
# 28 - 700
# 29 - 725
# 30 - 750
# 31 - 775
# 32 - 800
# 33 - 825
# 34 - 850
# 35 - 875
# 36 - 900
# 37 - 925
# 38 - 950
# 39 - 975
# 40 - 1000
# 41 - 1025
# 42 - 1050
# 43 - 1075
# 44 - 1100
# 45 - 1125
# 46 - 1150
# 47 - 1175
# 48 - 1200
# 49 - 1225
# 50 - 1250
# 51 - 1275
# 52 - 1300
# 53 - 1325
# 54 - 1350
# Total number of data jobs posted for Raleigh, NC in last 120 days - 424
# 0 - 0
# 1 - 25
# 2 - 50
# 3 - 75
# 4 - 100
# 5 - 125
# 6 - 150
# 7 - 175
# 8 - 200
# 9 - 225
# 10 - 250
# 11 - 275
# 12 - 300
# 13 - 325
# 14 - 350
# 15 - 375
# 16 - 400
# Total number of data jobs posted for Denver, CO in last 120 days - 563
# 0 - 0
# 1 - 25
# 2 - 50
# 3 - 75
# 4 - 100
# 5 - 125
# 6 - 150
# 7 - 175
# 8 - 200
# 9 - 225
# 10 - 250
# 11 - 275
# 12 - 300
# 13 - 325
# 14 - 350
# 15 - 375
# 16 - 400
# 17 - 425
# 18 - 450
# 19 - 475
# 20 - 500
# 21 - 525
# 22 - 550
# Total number of data jobs posted for Seattle, WA in last 120 days - 1065
# 0 - 0
# 1 - 25
# 2 - 50
# 3 - 75
# 4 - 100
# 5 - 125
# 6 - 150
# 7 - 175
# 8 - 200
# 9 - 225
# 10 - 250
# 11 - 275
# 12 - 300
# 13 - 325
# 14 - 350
# 15 - 375
# 16 - 400
# 17 - 425
# 18 - 450
# 19 - 475
# 20 - 500
# 21 - 525
# 22 - 550
# 23 - 575
# 24 - 600
# 25 - 625
# 26 - 650
# 27 - 675
# 28 - 700
# 29 - 725
# 30 - 750
# 31 - 775
# 32 - 800
# 33 - 825
# 34 - 850
# 35 - 875
# 36 - 900
# 37 - 925
# 38 - 950
# 39 - 975
# 40 - 1000
# 41 - 1025
# 42 - 1050
# Total number of data jobs posted for Atlanta, GA in last 120 days - 641
# 0 - 0
# 1 - 25
# 2 - 50
# 3 - 75
# 4 - 100
# 5 - 125
# 6 - 150
# 7 - 175
# 8 - 200
# 9 - 225
# 10 - 250
# 11 - 275
# 12 - 300
# 13 - 325
# 14 - 350
# 15 - 375
# 16 - 400
# 17 - 425
# 18 - 450
# 19 - 475
# 20 - 500
# 21 - 525
# 22 - 550
# 23 - 575
# 24 - 600
# 25 - 625
# Total number of data jobs posted for Boston, MA in last 120 days - 1249
# 0 - 0
# 1 - 25
# 2 - 50
# 3 - 75
# 4 - 100
# 5 - 125
# 6 - 150
# 7 - 175
# 8 - 200
# 9 - 225
# 10 - 250
# 11 - 275
# 12 - 300
# 13 - 325
# 14 - 350
# 15 - 375
# 16 - 400
# 17 - 425
# 18 - 450
# 19 - 475
# 20 - 500
# 21 - 525
# 22 - 550
# 23 - 575
# 24 - 600
# 25 - 625
# 26 - 650
# 27 - 675
# 28 - 700
# 29 - 725
# 30 - 750
# 31 - 775
# 32 - 800
# 33 - 825
# 34 - 850
# 35 - 875
# 36 - 900
# 37 - 925
# 38 - 950
# 39 - 975
# 40 - 1000
# 41 - 1025
# 42 - 1050
# 43 - 1075
# 44 - 1100
# 45 - 1125
# 46 - 1150
# 47 - 1175
# 48 - 1200
# 49 - 1225
# Total number of data jobs posted for New York, NY in last 120 days - 1777
# 0 - 0
# 1 - 25
# 2 - 50
# 3 - 75
# 4 - 100
# 5 - 125
# 6 - 150
# 7 - 175
# 8 - 200
# 9 - 225
# 10 - 250
# 11 - 275
# 12 - 300
# 13 - 325
# 14 - 350
# 15 - 375
# 16 - 400
# 17 - 425
# 18 - 450
# 19 - 475
# 20 - 500
# 21 - 525
# 22 - 550
# 23 - 575
# 24 - 600
# 25 - 625
# 26 - 650
# 27 - 675
# 28 - 700
# 29 - 725
# 30 - 750
# 31 - 775
# 32 - 800
# 33 - 825
# 34 - 850
# 35 - 875
# 36 - 900
# 37 - 925
# 38 - 950
# 39 - 975
# 40 - 1000
# 41 - 1025
# 42 - 1050
# 43 - 1075
# 44 - 1100
# 45 - 1125
# 46 - 1150
# 47 - 1175
# 48 - 1200
# 49 - 1225
# 50 - 1250
# 51 - 1275
# 52 - 1300
# 53 - 1325
# 54 - 1350
# 55 - 1375
# 56 - 1400
# 57 - 1425
# 58 - 1450
# 59 - 1475
# 60 - 1500
# 61 - 1525
# 62 - 1550
# 63 - 1575
# 64 - 1600
# 65 - 1625
# 66 - 1650
# 67 - 1675
# 68 - 1700
# 69 - 1725
# 70 - 1750
# 71 - 1775
# Total number of data jobs posted for Washington, DC in last 120 days - 2378
# 0 - 0
# 1 - 25
# 2 - 50
# 3 - 75
# 4 - 100
# 5 - 125
# 6 - 150
# 7 - 175
# 8 - 200
# 9 - 225
# 10 - 250
# 11 - 275
# 12 - 300
# 13 - 325
# 14 - 350
# 15 - 375
# 16 - 400
# 17 - 425
# 18 - 450
# 19 - 475
# 20 - 500
# 21 - 525
# 22 - 550
# 23 - 575
# 24 - 600
# 25 - 625
# 26 - 650
# 27 - 675
# 28 - 700
# 29 - 725
# 30 - 750
# 31 - 775
# 32 - 800
# 33 - 825
# 34 - 850
# 35 - 875
# 36 - 900
# 37 - 925
# 38 - 950
# 39 - 975
# 40 - 1000
# 41 - 1025
# 42 - 1050
# 43 - 1075
# 44 - 1100
# 45 - 1125
# 46 - 1150
# 47 - 1175
# 48 - 1200
# 49 - 1225
# 50 - 1250
# 51 - 1275
# 52 - 1300
# 53 - 1325
# 54 - 1350
# 55 - 1375
# 56 - 1400
# 57 - 1425
# 58 - 1450
# 59 - 1475
# 60 - 1500
# 61 - 1525
# 62 - 1550
# 63 - 1575
# 64 - 1600
# 65 - 1625
# 66 - 1650
# 67 - 1675
# 68 - 1700
# 69 - 1725
# 70 - 1750
# 71 - 1775
# 72 - 1800
# 73 - 1825
# 74 - 1850
# 75 - 1875
# 76 - 1900
# 77 - 1925
# 78 - 1950
# 79 - 1975
# 80 - 2000
# 81 - 2025
# 82 - 2050
# 83 - 2075
# 84 - 2100
# 85 - 2125
# 86 - 2150
# 87 - 2175
# 88 - 2200
# 89 - 2225
# 90 - 2250
# 91 - 2275
# 92 - 2300
# 93 - 2325
# 94 - 2350
# 95 - 2375
# Total number of data jobs posted for Columbus, OH in last 120 days - 299
# 0 - 0
# 1 - 25
# 2 - 50
# 3 - 75
# 4 - 100
# 5 - 125
# 6 - 150
# 7 - 175
# 8 - 200
# 9 - 225
# 10 - 250
# 11 - 275

# %%
data_jobs_df.count()
# Out:
# jobtitle                 10284
# company                  10284
# city                     10284
# state                    10284
# country                  10284
# language                 10284
# formattedLocation        10284
# source                   10284
# date                     10284
# snippet                  10284
# url                      10284
# onmousedown              10284
# jobkey                   10284
# sponsored                10284
# expired                  10284
# indeedApply              10284
# formattedLocationFull    10284
# formattedRelativeTime    10284
# stations                 10284
# dtype: int64

# %%
# displaying all job titles (to ensure the query returned all job titles included)

for _, row in data_jobs_df.iterrows():    
    
    print(row['jobtitle'])
# Out:
# Data Center Security Engineer
# Senior Engineer - Data Science
# Senior Business Intelligence Data Analyst
# Data Governance Program Manager
# Operations Analyst - Symitar System and Episys Data Structure
# R&D Data Analysis and Machine Learning Software Engineering Associate
# Machine Learning Engineer
# Data Scientist
# Data Base Administrator IV
# Lead Machine Learning Engineer
# Temporary Customer Data Specialist - UTemps
# Data Warehouse Architect
# Data Manager
# CPA - Data Analysis and Transparency Intern
# Clinical Data Reporter
# Data & Analytics - eCommerce
# Backend Software Engineer - Data Platform
# Data Entry Clerk
# Junior Tableau Consultant (Entry Level)
# Data Scientist
# Data Science
# Special Education Data Support Analyst (Data Analyst V)
# Sanctions Data Analyst
# Data Entry / Lab Assistant
# Business Intelligence Analyst
# Director, Data Science - Round Rock, TX
# Data Engineer
# Data Center Operations Analyst / Network Administrator - Austin, TX
# Data Analyst / Integrations Analyst- Intern
# Big Data Lead
# AI Technology Lead
# Senior Data Engineer
# Product Manager, User Data Platform
# Sr. Product Manager, Data
# Senior Data Administrator
# Data Analyst
# Summer 2020: Machine Learning Intern
# Sr. Data Governance Manager
# Data Center Analyst
# Tableau Admin
# Research Data Analyst
# NHATS 2020 – Data Collector
# Data Architect- San Jose
# Enterprise Data Architect
# Data Architect
# Principal Data Manager
# System Analyst V - Data Center Coordinator
# Data Entry Opportunities in Austin
# Data, phone, service tech
# Data Entry/Warehouse Associate
# Inside Solutions Engineer - Data Center - Corp ASG
# Lead Data Acquisition Electrical Engineer
# Full Time Bi-lingual Retail Associate Needed
# Data Designer - Communications Division
# Data Scientist
# Analyst, Business Intelligence
# Big Data | Hadoop Developer
# Ediscovery Data Operations Specialist
# IT Data Architecture/Data Migration Student Intern
# Data Analyst - A/B Testing
# Data Engineer
# Data Analyst - A/B Testing
# AI Engineer
# Data Science & Analytics Intern - Summer 2020
# Associate SalesForce.com Data Steward & Analyst
# Senior Software Engineer - Data Pipeline
# BI/Tableau Developer
# Data Scientist - Round Rock, TX
# Senior Machine Learning Engineer – Infrastructure : Duo Security
# Software Engineer-Data Science PHD (Intern)-United States Duo Security
# Senior Software Engineer, Data Engineering - Duo Security
# CRM and Data Engineer (Zoho One)
# Data Entry Clerk
# Data Analyst
# Research Data Coordinator
# Data Operations Specialist
# WIC Senior Data & Reporting Analyst
# Data Engineer
# Data Analyst IV(SQL, Finance , Executive Communication)
# Machine Learning & AI Internship | Winter and Spring Programs
# Data Analyst
# Regional Head of Business Development - AI & Machine Learning Solutions
# Quality Systems Data Administrator
# Data Analyst/Business Intelligence Developer
# Data Scientist
# Data Engineering Manager
# Data Architect - Data Lake & Analytics - Nationwide Opportunities
# Data Transcriber - DEPARTMENT OF TREASURY - IRS
# Data Scientist (Contract)
# Aggregation Data Maintenance Associate - Japanese
# Data Conversion Business Analyst
# Sr Data Architect - Data Warehouse & MPP - Nationwide Opportunities
# Practice Leader - Data & Analytics
# Sr Data Architect - Data Lake & Analytics - Nationwide Opportunities
# Data Entry Specialist Temp
# Data Engineer
# Data Ops Engineer
# Data Engineer
# Insurance Data Analyst
# Health Data Analytics Student Intern
# Data Warehouse Architect
# Data Engineer
# Financial Data Analyst
# Sr. Data Analyst
# Data Engineer
# HR Data Analyst Intern
# Big Data Platform Engineer
# Data Engineer
# Expert Tableau Program Analyst
# Account Manager - E-Commerce Machine Learning
# Senior Statistician
# Senior Data Engineer
# Senior Manager, Data Governance and Information Security
# Senior AI Engineer
# Sr. Application Support Engineer (AI)
# Senior Analog Design Engineer - Data Converters
# Big Data Developer
# Data Analyst (TX)
# Senior Data Warehouse Engineer
# Software Engineer – Data Services
# Clinical Data Manager II
# Data Engineer
# Senior Clinical Data Manager
# Lead Software Engineer – Data Services
# Sr. Data Engineer
# Data Scientist - Sports Analytics (Full-Time, Entry-Level, Summer 2020)
# BI Data Analyst
# Program and Performance Analyst (Data Analyst IV)
# Video Analytics/Machine Learning Engineer, 3rd Eye
# Data Analyst IV
# Sr BA - Business Intelligence
# Data Analyst IV
# Senior Machine Learning Engineer
# Full Time Data Entry Position
# Data Engineer
# Full Time Data Entry Position
# Sr. Developer for Data Migration
# QA Manager, Data & Analytics
# Data Security Administrator
# SAP BI / BW HANA Consultant
# Data & Compliance Associate
# Data Engineer
# Senior Data Engineer
# Data Modeling/Architecture Consultant
# Data Engineer
# Principal BI Engineer
# Lead Provider Data Management Specialist
# Data Communications Technician
# Data Scientist
# Data Reporting Compliance Monitor
# IT Data Architect (Data Integration Developer and ETL Toolset Administrator)
# Staff Data Scientist - Visa Research
# Associate Data Scientist
# Data Repository Developer
# Summer 2020 Intern, Artificial Intelligence (Austin)
# Data Analyst Specialist/Apprentice
# Business Process Data Analyst
# Data Standards & Governance Manager (Manager V)
# Data Analyst
# Data Analyst
# INTERNAL REVENUE SERVICE - Data Transcriber
# Data Management Specialist
# Billing/Data Entry Processing Representative
# Salesforce Acquisition Integration Data Specialist
# Billing/Data Entry Processing Representative
# Senior Data Scientist
# Summer 2020 Machine Learning Co-Op/Intern - (77293)
# Marketing Data Analyst
# Data Science Analyst
# Data Architect ISY
# Marketing Statistician
# Data Engineer (ATX)
# Fixed-Income Data Engineer
# Quantitative Data Analyst or Senior Analyst- External Private Markets Data Analytics
# Sr Data Engineer
# Data Architect
# Cloud Data Engineer
# Supervisor, Provider Data & Credentialing
# Data Support Engineer
# Data Science Engineer
# Product Manager, Data Acquisition
# Data/Integration Engineer with Active Clearance
# Data Engineering Manager
# Summer 2020 AI/ML Research Co-Op/Intern - 77150
# Senior AI Engineer
# Senior Data Engineer (Big Data-Cloud/Python/SQL)
# Senior Process Executive-Data
# AI Software Engineer - NBA Live
# Software Engineer, Data Platform
# Staff Software Engineer-Data Product Development
# Cloud Enablement, Manager – Data Delivery (Azure)
# Staff Software Engineer, Data Product Development - Geospatial Location Systems
# Cloud Enablement, Senior Consultant – Data Delivery (Azure)
# Lead Software Solutions Specialist, STT Data Management
# Bi-lingual (English/Spanish) Assistant Manager
# Data Scientist
# Senior Business Intelligence Analyst
# Power BI Developer
# Business Intelligence Analyst
# Business Intelligence Analyst / Developer - 77287
# Big Data Spark Developer
# Senior Data Scientist - Round Rock, TX
# Data Protection Regional Business Operations Consultant (AMER)
# Data Scientist
# Big Data Solutions Architect
# Receptionist/Data Entry
# Data Analyst Intern - North American Power
# BI Reporting Systems Analyst
# Salesforce Acquisition Integration Data Specialist (HID658)
# Data Scientist Intern for Enterprise Analytics
# Senior BI and Analytics Manager
# Google Data Engineer
# Data Engineer
# Data Engineer- Data Platform
# Software Engineer, Data - Innography
# Data & Software Engineer
# Product Manager, Data Platform
# Lead Data Scientist IV, Central Analytics
# Engineering Manager - Data Platform
# Cloud Enablement, Manager – Data Delivery (GCP)
# Cloud Enablement, Senior Consultant – Data Delivery (GCP)
# Cloud Enablement, Manager – Data Delivery (AWS)
# Cloud Enablement, Senior Consultant – Data Delivery (AWS)
# Staff Data Architect
# Machine Learning Scientist
# Manager of Business Intelligence
# Data Engineer
# TMD - Programmer III (Business Intelligence Developer)
# Business Development Executive for Data Service Company
# Gifts and Data Services Coordinator
# Data Entry Clerk
# Data Specialist
# Data Engineer
# Data Analyst
# Data Entry Specialist I
# Data Operations Specialist
# Machine Learning Engineering Manager
# Data Governance Subject Matter Expert (SME)
# Statistician
# Salesforce Acquisition Integration Data Specialist
# VP of Data Science
# Clinical Research Data Entry Coordinator
# Salesforce Acquisition Integration Data Specialist
# Senior Data Engineer
# Senior Database Administrator (Data Base Administrator IV)
# Senior Data Analyst
# Sr. Data Architect
# Associate Data Scientist ( 6 Month Contact)
# Senior Data Scientist
# Principal Consultant - Data Strategy
# Data Engineer
# School Receptionist and Data Clerk (Excel Charter School)
# Lead, People Analytics-Data Science
# Data Engineering Project Manager
# Sales Business Intelligence
# Data Engineer - Associate
# Data Engineer
# Manager, Data Science
# Clinical Data (Data Entry) Operator I Swing Shift, Tuesday-Saturday
# Data Engineer II
# Sr. Data Engineer
# Lead Data Engineer
# Manager, Workday Data Conversion Lead
# Software Engineer II, Data Science
# Manager, Data Engineering
# Cybersecurity Engineer - Data Security
# Cybersecurity Principal-Architect – Data Security
# Lead Java Architect - Data Product Development, Digital Marketing Experience
# Cybersecurity Staff-Lead Engineer – Data Security
# Cybersecurity Senior Engineer - Data Security
# Sr. Data Engineer
# HEDIS Data Analyst
# Senior Marketing Analytics Partner - Marketing Business Intelligence Reporting
# Senior Data Scientist (SMS)
# Technical Curriculum Lead, Data Engineering and Analytics
# Sr. Advisor, Business Intelligence
# Cloud and Data Center Analyst
# Data Scientist
# Data Science Analyst
# Data Analyst – University Graduate
# Data Analyst II
# Data Integration Engineer
# Clinical Data Operator 1
# Data Clerk - Payroll Transportation - 1st Shift
# Data Engineer IV
# Cloud Technical Solutions Engineer, Big Data
# MDM - Master Data Management-Consultant
# Software Developer - Big Data
# Senior Analog Design Engineer - Data Converters
# Azure Data Specialist
# Systems Engineer - Data Intelligence
# Machine Learning Engineer
# Transformation Data Scientist - Austin, TX
# Data Base Administrator IV
# Data Engineer
# Senior Advisor - Marketing Operations: Business Intelligence
# Senior Data Scientist
# Data Engineer
# Data Center Security Administrator (Physical Security) - Night Shift
# Senior SQL Developer - Data Migration
# Sr. Data Engineer
# Senior Data Engineer
# Sr. Manager, Data Engineering
# Solution Architect, Data Services
# Sr. Data Engineer (REF21633Y) - Visa Digital Developer Platform (VDDP)
# Staff Software Engineer (Commercial Cards - B2B Services)- Data Product Development
# Product Manager - Data Platform
# Robotics Engineer Artificial Intelligence
# Insight and Data Analyst Internship
# Data Scientist
# Data Systems and Reporting Analyst
# Data Center Health and Safety Professional
# Medical Lab Scientist I, Data Reviewer (Temporary)
# Vice President of Data Analytics (Immediate Opening)
# VP Early Development Data Operations
# Data Engineer
# Senior Machine Learning Data Scientist
# Director, Data Science & Advanced Analytics
# Data Analyst, Supplier Diversity
# ETL / Tableau Developer
# Client Accelerators Data & Insights Specialist
# Data Base Administrator
# Senior Data Scientist
# Senior Big Data/AI-ML Developer
# Salesforce Data Analyst
# Data Warehouse Architect
# Social Services Data Quality Associate
# Finance Operations Analyst - Data Center Infrastructure
# Clinical Data Manager
# Data Base Architect
# Senior Data Analyst - Product and User Insights
# Enterprise Architect (Data Architect)
# Manager, Data Engineering
# Big Data Platform Engineer
# Enterprise Data Catalog Consultant
# Solution Architect - Enterprise Business Intelligence & Analytics (EBIA) - Digital-IT
# Senior Data Engineer
# Axon Data Governance Consultant
# Data Capture Software Developer
# Salesforce Data Architect
# Sr. Manager, Machine Learning Software Development - 76884
# Client and Market Growth Data & Insights Lead
# Staff System Engineer for Big Data Reliability Engineering
# Data Governance Automation Lead
# Specialist SA, Machine Learning/AI Services
# Associate Data Analyst (Entry Level)
# Business Intelligence Developer
# Data and Analytics Solution Architect
# Technical Curriculum Lead, Machine Learning, Google Cloud
# Senior Power BI Developer
# Director - ML Pipelines for AI Consultant
# Data Systems Developer
# Healthcare Data Engineer
# Data Analyst Intern (Summer 2020)
# Data Sales Manager
# Research Associate / Data Specialist
# Data Reporting Compliance Monitor (Systems Analyst V)
# Data Specialist
# Senior Data Analyst
# Data Quality / Fraud Investigator (DQFI)
# Data Science & Analytics Technical Lead
# Data Entry Operator
# Senior Business Analyst (Data)
# Data Engineer
# Data Center Network Architect
# Manager, Advanced Data Insights
# Marketing Data Analyst
# Global Product Data Management Lead Specialist- Austin, TX
# Engineering Manager - Data Services
# Data Pipeline Software Engineer
# AI Platform Software Architect
# Master Data Management, Senior Consultant - Data Delivery (Informatica MDM/360)
# Senior Software Engineer, Data Platform
# Lead Software Engineer – Data Services
# Manager, Machine Learning Solutions Lab
# Business Intelligence Consultant
# Inside Data Protection Specialist - Round Rock, TX or Franklin, MA
# Site Reliability Engineering Manager - Data Infrastructure
# CPA - Senior Data Administrator (reopened)
# Data Entry Clerk
# Data Science Consultant - Round Rock, TX
# Enterprise Data Architect
# Data Analyst
# Tableau Developer
# Product Management Consultant (AI) - Austin, TX or Durham, NC
# Data Science Interns
# Product Marketing, Advisor (Data Center Infrastructure - APC) Round Rock, Nashville
# SAP Ariba Data Consultant
# SAP IBP Data Consultant
# SAP Product Lifecycle Management Data Consultant
# Sr. Data Center Delivery Engineer
# GPU-Accelerated Data Analytics Software Intern
# Associate Consulting Engineer – Federal (Data Center, MS-Azure, Network Security)
# Data Specialist, Community Operations
# Data Scientist
# Machine Learning (ML) Solutions Engineer - 76331
# Data Privacy Advisor
# CPA - Expenditure Audit Data Analyst
# Software Development Engineer, Cloud-Scale Machine Learning Acceleration
# Computer Science Instructor (On-ground)- Data Structures and Algorithms
# Senior Strategy Data Analyst
# Senior Data Engineer
# Senior Designer, Data Visualization
# System Engineer, Data Migration subject matter expert (SME),
# Senior Data Warehouse Engineer
# Data Scientist - Aerospace and Defense Industry
# Artificial Intelligence Engineer
# Data Transcriber *SEASONAL* **6 Month Register** (Data Entry Clerk)
# Data Entry Clerk
# Data Entry Specialist
# Business Intelligence Engineer
# Data Scientist - Oil & Gas Industry
# Machine Learning GPU Kernels Performance Software Engineer - 75789
# Data Analyst
# Data Engineer
# Technical Writer - Data Model
# Field Marketing & Events Manager - Midwest - AI-driven Revenue Operations
# Artificial Intelligence Consultant, CMT Southwest
# Data Scientist
# Senior Data Analyst
# Artificial Intelligence Manager, CMT Southwest
# IT Business Intelligence Developer
# Technical Trainer - Data Encryption & Crypto Management
# Senior Business Intelligence Analyst
# Senior Business Intelligence Analyst
# Sr. Data Analyst
# Sr. Marketing Operations and Data Analyst
# Senior AI Engineer
# Director of Data & Analytics - Austin
# Senior Software Engineer- Data Product Development
# Staff Software Engineer- Hadoop - Visa Business Solutions Products- Data Product Development
# Machine Learning Researcher
# VP - Data & Analytics
# Software Development Engineer Fungible- AI & Machine Learning (Last Mile Delivery)
# Immigration Data Clerk
# Data Entry Project Starting Friday, 9/27
# Data Engineer
# Data Engineer
# Accounting Analyst – Production Data
# Big Data Lead/Developer
# Oracle Business Intelligence(BI) Consultant
# SCRUM 2 Power BI Dev
# Research Engineer - Machine Learning for Autonomous Driving Behavior
# Data Scientist (Austin)
# Associate Business Intelligence Analyst
# Data Modeler
# Tableau Developer
# Business Analyst- Tableau
# Product Cost Data Scientist
# BI Analyst (Financial/Accounting Data)
# Data Architect
# Azure BI - Build Foundations Report Developer
# Customer Success Associate - Austin, TX - AI-driven Revenue Operations
# Data Solutions Engineer
# Data Engineer
# Senior Front-End Engineer, Data Hub
# Senior Software Engineer, Data Science
# Data Analyst
# Tableau Developer
# Sr. Associate Data Scientist - Sales Science Strategy & Capabilities
# Market Data Analyst Associate
# IT Data Engineer Applications - SAS, SQL
# Data Analyst
# Big Data/Hadoop Developer
# Senior Data Modeler with Healthcare- Payer exp
# Sr. Associate Data Scientist - Sales Science Strategy & Capabilities
# Data Governance Analyst
# Data Scientist
# Data Analyst
# Analytic Consultant 4 - Data
# Clinical Data Consultant
# Data Maintenance Analyst
# Senior Data Analyst, Customer Engagement
# Data Analyst
# Senior Software Development Engineer - Machine Learning - OCI Data Science Cloud Service
# Director – Financial Data Systems
# Data Analyst - Int
# Business Intelligence & Reporting Developer
# Business Intelligence Engineer, Mulesoft
# Content Strategist, Data Products
# Accessioner Data Entry (Part Time)
# Senior Data Engineer Banking
# Senior Product Manager, Data
# AI / Machine Learning Engineer
# Investment Analyst with Data Visualization (Tableau) Skills
# Data Analyst
# BUSINESS INTELLIGENCE DATA ANALYST - HEALTHLINE
# Big Data Engineer with AWS
# Big Data Architect
# Data Analyst
# Senior AI Backend Engineer
# Principal Data Architect, Data Warehousing & MPP
# Data Analyst - Intermediate [136527]
# HEALTH SERVICES DATA ANALYST
# Tableau Developer
# Big Data/Hadoop Developer
# Big Data Developer
# Data Engineer
# HEALTH SERVICES SUPPORT DATA ANALYST
# THE 2020 LAUNCH PROGRAM: DATA ANALYST INTERN - HEALTHLINE
# Machine Learning Engineer II
# Sr. Data Scientist II -Freight Marketplace
# Data & Reporting Specialist, Trip Development
# Big Data Tech Lead
# Applied Machine Learning Intern
# SR. DATA ENGINEER
# AppD Security Data Analyst Bachelor's (Intern) United States
# Senior Data Warehouse IT Architect
# Data Engineer/Developer
# Director, Clinical Data Management
# Data Engineer
# Director of Data Science
# Data Analyst
# Data Analyst Int. Contractor : 20-00059
# Senior Software Engineer, Customer Directory (Data)
# Sr. Biomedical Data Manager II
# Director, Clinical Data Management
# Data Center Manager Intern
# Sr. Data Engineer / Back-End Engineer
# Senior Data Analyst / Full Stack Developer - San Francisco or San Jose, CA
# Senior Data Analyst / Full Stack Developer
# Machine Learning Engineer
# Business Intelligence Analyst
# Data Scientist
# Summer Intern - Machine Learning
# Sr. Data Analyst
# Business Intelligence Analyst, People Operations
# Data Scientist - Inference
# Data Scientist
# People Analytics Data Analyst
# Staff Data Scientist (Audiences Team)
# Business Operations Data Analyst
# Senior Data Organizer
# Big Data /ETL Tester/QA
# Business Intelligence Developer
# Senior Data Scientist
# Consumer Credit Manager (Business Intelligence, Decisioning and Implementation)
# Scientist - Computational Biology & Statistical Genetics
# SQL Data Analyst
# Bioinformatics/Data Science Internship
# Data Engineer
# Data Analytics Intern
# Executive Director - Product Owner Data strategy and Governance
# Data Analyst - Via Licensing
# Data Architect
# Director, FSS Finance Data Management and Analytics
# Data Science Intern
# Data Analyst
# Senior Software Engineer, Machine Learning
# Senior Data Engineer
# Manager, Data Science
# Oracle Data Cloud (ODC) - DMP Sales
# Data Solutions Architect - (VMware Tanzu) San Francisco, CA
# NPI Data Center Program Manager
# Principal Data Manager
# Data Center Tech Intern
# Product Manager, Data Analytics
# Field Solutions Engineer - Data Center - Corp ASG (San Francisco)
# Field Engineer | Data Acquisition Group
# Senior Product Manager, Global Data Tools
# Director, Product Management, Customer Data Platform_Marketing Cloud
# Cyber Data Privacy Senior Consultant
# Principal Product Manager, Analytics & Data Platform
# Data Scientist
# Imaging Data Assistant
# Data Scientist II
# Power BI Developer (Locals Only)
# Presto Data Engineer
# Director - Clinical Informatics and Data Science
# Data Scientist
# Intake Worker and Data Management
# Data Scientist - Risk
# Director - Clinical Informatics and Data Science
# Senior Data Modeler (Locals Only)
# Product Manager- Data & Analytics
# Data Analytics and Business Planning Manager – Global Visa Direct Commercialization
# Reimbursement Specialist / Healthcare AI Trainer
# Data and Systems Analyst
# 2020 Data Engineering Summer Intern
# Director of Software Development, Vulnerability Business Intelligence
# Data Analyst - Asset Management
# Data Analyst
# Bi-lingual (Spanish) Client Advocate
# Data Engineer II
# Senior Data Scientist
# Data Analyst
# Staff Data Engineer
# Software Data Engineer, Threat and Vulnerability Management Engineering
# Senior Data Engineer
# Manufacturing Engineer--Data Analytics
# Bi-lingual Children’s Mental Health Therapist
# Bi-lingual (Spanish) Customer Service Associate
# Senior Machine Learning Engineer - Webex Intelligence
# Data Scientist
# Business Intelligence Analyst - Cloud Security
# Lead Data Platform Engineer
# Clinical Data Operator 1
# Senior Software Engineer, Data
# Data Analyst
# Data Analyst
# Senior Manager, Data Science and Machine Learning
# Senior Data Scientist
# Data Engineer, Mulesoft
# Data Technologies Operations & Support Engineer
# Data Engineer
# Product Manager, Data and Insights
# Data Architect, Staff
# Data Engineer
# Data Analytics Manager (EPIC)
# Intern, Data Engineering
# Cyber Data Governance Consultant
# Senior Data Scientist ( Need Locals )
# Tableau Developer II
# Sr. Data Analyst
# Clinical Data Manager for CRO
# Big Data Engineer
# Innovation Labs - Data Science Internship
# Cyber Data Governance Senior Consultant
# SAP Data Architect - Senior Consultant (Technology)
# SAP Data Architect– Manager (Technology)
# SAP BODS/Data Services Developer - Senior Consultant (Technology)
# SAP BODS/Data Services Developer– Manager (Technology)
# Senior Natural Language AI & Machine Learning Engineer w/ Web Skills
# Power BI Consultant
# Regional Head of Business Development - AI & Machine Learning Solutions
# Staff Product Manager - Machine Learning Ethics, Transparency and Accountability
# Machine Learning Engineer
# Summer 2020 Machine Learning Intern
# Data Architect
# BI Data Analyst/Modeler
# Machine Learning Engineer
# Program Data Specialist
# Senior Data Scientist, Insights and Analytics
# Data Technician
# Senior Natural Language AI & Machine Learning Engineer w/ Web Application Skills
# Process Data Engineer
# Mobile Engineer (Machine Learning/Computer Vision)
# Machine Learning Developer - Deep Learning
# Contingent: PWM Data and Reporting Analyst
# Big Data/Hadoop Developer
# Data Engineer - Deep Learning
# Senior Data and Project Analyst
# Senior Data Scientist
# Manager, Business Intelligence
# Data Engineer
# Research Data Analyst
# Contractor: PWM Data Analyst, Ecosystem
# Senior Data Scientist
# Machine Learning Engineer – PhD Hire
# Senior Data Analyst, Analytics and Business Intelligence
# Business Intelligence Analyst
# Senior Machine Learning Engineer, Semantic Knowledge
# Collections Data and Media Systems Administrator
# Data Scientist
# Senior Business Intelligence Analyst
# Data Engineering Support Lead
# BI Engineer (Reporting)
# Contractor: PWM Data Analyst, Digital Experience
# Data Administrator
# Data Engineer - CIMD - Marcus by Goldman Sachs Engineering
# BI DEVELOPER
# Manager, Statistical Analyst
# Delivery Manager for Big Data Project
# Triage & Data Analyst (Hines@Facebook)
# Human Resources Payroll and Data Entry Specialist
# Data Engineer, AAG Engineering
# Lead Data Engineer
# Lead Data Engineer
# Senior Data Scientist- Consumer Product- Metrics Team
# Senior Data Platform Architect
# Senior Data Infrastructure Engineer (Data Team)
# Senior Data Analyst
# Financial Systems Data Analyst
# Senior Data Scientist
# Senior Data Engineer, OneView
# Data Engineer/Architect
# Senior Data Engineer
# Sr. Business Development Data Analyst
# Data Analytics Manager - Investigative Analytics (Financial Services)
# Senior Bioinformatics Scientist, Data Analysis, Minimal Residual Disease
# Sales Analytics and Solutions Program Manager, Data Security
# AI Security Architect
# Senior Software Engineer, Data Team
# Inside Sales Representative for Data Protection
# Product Support Sales Representative - Data Center
# Software Engineer, Data Infrastructure (People Analytics)
# Data Engineer
# Entry Level Azure Data Engineer
# Data Scientist - Canada
# Intern, Machine Learning Robotics
# Data Engineer
# Data Engineer
# Data Scientist
# Data Scientist
# VP of Data Science
# Data Analyst Early Learning
# Validation Engineer - Data Intelligence Computer Systems in Pharmaceutical
# Data and Evaluation Manager
# Data Analyst (Mobile Gaming)
# 2020 Summer Internship Data & Analytics | Forensic and Litigation Consulting - San Francisco
# Data Scientist | Planning & Algorithm Controller
# Data Engineer - Canada
# Data Analyst
# Data Specialist
# Data Architect
# Senior Machine Learning Engineer
# 2020 Summer Consultant Data & Analytics | Forensic and Litigation Consulting - San Francisco
# Data Governance Lead
# Data Analyst
# Data Specialist (Civil Rights)
# Senior Data Scientist
# Data Engineer
# Data Science Internship
# Data Communications Tech
# Junior/Senior Statistical Programmer Analyst Consultant
# Business & Data Analyst - San Francisco or San Jose, CA
# Sr. Data Analyst for Innovative Health Plan
# Lead BI & Data Engineer
# Data Science Manager
# Data Specialist
# Associate Business Intelligence Analyst – Business Planning
# Senior Data Scientist
# Proposition Sales - Pricing and Reference Data
# Data Specialist (CLERICAL)
# Senior Data Scientist - Economist - Freight Marketplace
# Lead Data Analyst
# Manager, Data Science
# Data Entry Specialist (Shift 2)
# Senior Data Engineer
# Cloud Data Architect-AWS
# Data Engineer
# HR Data and Process Specialist
# Marketing Data Analyst
# Data Science Search Intern
# Senior Data Engineer
# Data Analyst
# Data Engineer, Analytics
# Senior Software Engineer, Machine Learning Operations
# Clinical Trial Statistical Programmer
# Data Specialist (Civil Rights)
# Data Consultant, Sales Analytics
# ML/Data Science Intern (Summer 2020)
# Director, Research & Data Partnerships
# Data Engineer
# Experienced Data Security and Compliance Consultant
# Post Doctoral Researcher, Data Science/Generative Networks- ATOM Consortium
# Director - Data Engineering Lead
# Data Engineer
# Web & Data Manager
# Manager II, Data Analytics
# Administrative Data Intern - Unpaid
# BI Underwriting Development Program - Walnut Creek Summer '20
# Clinical Data Manager II
# Senior Clinical Data Manager
# Warehouse Data Processing Clerk
# Data Privacy Analyst Intern (2020)
# Data Architect
# Machine Learning Scientist
# Business Intelligence Lead Analyst
# Data Scientist 1
# Machine Learning SDET
# Voter Data Analysis and Programs Manager
# Data Specialist
# Head of Data
# Data Scientist, Business Analytics
# Data Scientist
# AI Engineering - Machine Learning Engineer
# Applied Data Ethics Fellow
# VP, Data Science
# Data Specialist
# Data Scientist
# Research Data Scientist
# 2020 PhD Data Scientist Internship - Rides
# Data Analytics Product Manager up to $250,000
# AI Engineering - Senior Machine Learning Engineer
# Data Engineer
# Data Engineer
# Sr. Business Intelligence Engineer
# Analytics/Business Intelligence Engineer
# Business Intelligence Manager
# Artificial Intelligence Lead
# Data Analyst
# Big Data Developer
# POWER BI Developer for long term contract in San Ramon, CA
# Assistant Director of Enrollment Data Systems
# Data Architect
# Data Engineer
# Director of Engineering, Data
# Manager, Data Warehouse & Analytics
# Postdoctoral Fellowship, Data Institute
# Software Engineer (Machine Learning)
# Senior Business Intelligence Developer
# Data Manager
# Data Quality Analyst
# Data Scientist, Product Analytics
# Data Specialist (Bus Maintenance)
# Data Analyst
# Data Specialist/Data Analyst
# Business Intelligence Analyst
# Data Science Product Owner
# Applied Data Ethics Research Fellow
# Manager, Business Intelligence
# Payment Data Entry Clerk
# Data Systems Analyst
# Data Scientist / Senior Data Scientist, Human Genetics
# VP BDL Digital & Data Science Partnerships
# Data Engineer (SF)
# Data Engineer
# Data Library Engineer
# Data Engineer
# Data Scientist - Marketing Analytics
# Data Analyst, US Carriers
# Data Platform Engineer - Personalization
# Data Engineer
# Senior Data Analyst
# Data Analyst
# Principal Data Scientist
# Cyber Security Data Scientist
# Senior Data Quality Analyst
# Staff Data Scientist-Auris Health (Robotics)-Redwood City, CA
# Engineering Manager - Data Science
# Data Scientist (Senior Associate) - Industry Program
# Data Analyst
# Manager of Data Science
# Senior Data Scientist
# Associate Director*, Statistical Programming
# Marketing Data Analyst
# Senior/Staff Data Scientist
# Principal Data Engineer
# Project Manager- Data and Technology (SF)
# Program Manager, Data Center Product Lifecycle Management
# Data Engineer
# Data Protection Manager
# Senior Data Engineer
# Intern, Data Engineering
# Data Analyst
# Machine Learning / Signal Processing Engineering Intern (Summer 2020)
# Data Engineer
# BI Engineer
# Data Engineer - Supply & Demand Planning
# Product Data Specialist
# Data Lead
# Senior Data Engineer
# Summer Intern, Statistical Programming, Biometrics
# Senior Big Data Engineer
# Senior Manager Data - Medicare Business Analytics
# Software Data Engineer
# Data Center Facilities Engineer (5194U)
# Data Center Structural Field Engineer
# Lead Software Engineer, Data
# Senior Engineer, Data Platform
# Senior Data Product Manager
# Data Software Engineer - Fraud
# Associate Data/Systems Analyst
# Manager, Insights Data Center Consultant
# AHD Minimum Data Set (MDS) Coordinator - PB
# Senior / Lead Data Engineer
# Software Engineer, Data Science
# Data Consultant II, NexGen Cost Accounting Program (2 year duration position)
# Sr. Manager/Director, Data Science
# Data Science Manager - Technology
# Manager II, Data Analytics, Ecomm
# Case Manager III (Bi-Lingual Spanish/English)
# Research Programs Lead- Health and Sciences- Berkeley Institute for Data Science
# Data Specialist (Bus Maintenance)
# Cloud Enablement, Manager – Data Delivery (GCP)
# Cloud Enablement, Manager – Data Delivery (Azure)
# Cloud Enablement, Senior Consultant – Data Delivery (Azure)
# Data Center Operations Engineer - Intern
# Cloud Enablement, Senior Consultant – Data Delivery (GCP)
# Cyber Security Data Scientist (Lead/Principal Cyber Security Analyst)
# Data Center Electrical Field Engineer
# Cloud Enablement, Senior Consultant – Data Delivery (AWS)
# Cloud Enablement, Manager – Data Delivery (AWS)
# IT Data Governance Program Manager
# Outside Sales - Emergency Fueling - Data Centers
# Business Intelligence Manager
# AI Scientist - Symbolic AI (Natural Language Reasoning)
# Data Scientist
# Machine Learning Engineer/ Deep Learning
# Data Visualization Analyst
# Head of Data
# Power BI Developer
# Data Scientist
# Staff Data Scientist - Deep Learning
# Machine Learning Engineer
# Machine Learning Infrastructure Engineer
# Data Engineer
# Data Analyst [AWS Experience]
# Senior Data Analyst- Product
# Data Scientist
# Data Analytics Manager
# Data Scientist
# Data Scientist - Quantitative Strategy
# Senior Director of BI & Analytics
# Manager, Data Architecture
# Senior Data Engineer
# BI Data Engineer - Platform Analytics
# Data Engineer - SAN FRANCISCO, CA or ARLINGTON, VA
# Staff Data Scientist - Data Science
# Staff Data Scientist
# Principal Data Architect
# Data Engineer
# Data Science Intern
# Data Scientist
# Statistical Modeling & Forecasting Scientist
# Data Analytics Manager
# Strategy & Ops Lead - Twitter Machine Learning Org
# Tableau Report Developer
# Staff EE Data Americas
# Associate Data Scientist
# Chief Data Scientist
# Finance Data Analyst
# Business Intelligence Analyst
# Big Data Engineer
# Data Engineer
# Power BI Developer with T-SQL
# Data Scientist
# Data Scientist (Computer Vision)
# Data Engineer
# Sr Manager, Data Architecture
# Data Wrangling Engineer
# Data Engineer
# Enterprise Data Management Specialist
# Data Integration Engineer
# Google Data Engineer
# Data Engineer
# Staff Data Scientist
# Sr Analyst, GTM Data Operations & Analytics
# Data Center Network Engineer
# Data Consultant
# SAP MDG Data Management Consultant
# Team Coordinator EE Data & Rewards Services Americas
# Data Scientist
# Data Science Manager
# Data Engineer
# Engineering Manager - Data Engineering
# Principal Data Engineer
# Manager, Statistical Analyst
# Senior-Lead Machine Learning Engineer (Perception)
# NESAP for Data Postdoctoral Fellow
# Vice President, Data Engineer, APG-SITE-Data Services
# SAP Data Conversion - MDG, BODS, Information Steward, SDI, MDM, DQ, SDQ, SAP Master, Data Management
# Principal Data Engineer
# Senior Data Engineer - Data
# VP Marketing, Strategy, Analytics & Data Science
# Engineer (Data Caching)
# Senior Marketing Data Scientist
# Data Steward Manager
# Workday Certified Data Consultant
# Director of Product Management - Getting Data In
# Data Visualization Engineer
# Staff Data Scientist
# Sr. HRIS Data Analyst
# Senior Data Science Engineer
# Director, Product Management - Data
# Enterprise Data Management Associate Manager
# Customer Success Manager, Data Vertical
# Azure Technical Architect - Azure Databricks, Data Factory, Event Hub, Azure SQL DB
# Business Intelligence Analyst
# Senior Data Engineer - Data Analytics
# Senior Data Engineer - Data Analytics
# Maintenance Data Systems Specialist
# Lead Data Science Engineer
# Workday- Certified Data Manager
# Data Strategy Lead - Cloud, AWS, Azure, GCP, Consulting Experience, Team Lead
# Staff Backend Engineer, Data Analytics
# Software Engineer - Big Data Engineering
# Principal Product Manager, Data
# Senior Principal Data Analyst
# Senior Data Scientist, Computational Biology
# Lead Data Scientist IV, Central Analytics
# Data Visualization Development Intern (Summer Session, Burlingame, CA)
# Senior Data Scientist
# Sr. Engineering Manager - Getting Data In/Integrations
# Sr. Software Engineer, Frontend - Experimentation & Data Visualization - Frontend
# Senior Engineer, Data Platform
# Manager-Senior Manager, Clinical Data Management
# Workday- Certified Data Assoc Mgr
# Senior Manager, Marketing Data Science
# Lead, Technical Recruiting (Product & Data)
# Senior Engineering Manager, Data Visualization Platform
# Senior Software Engineer, Data Infrastructure - Data
# Lead Combat/AI Designer
# Senior Software Engineer, Data Platform
# Senior Product Manager - Application Data Collection
# Software Engineer, Machine Learning
# Software Engineer, Data & Data Infrastructure
# Platform Curator, Artificial Intelligence and Machine Learning Centre for the Fourth Industrial Revolution
# Applied Machine Learning engineer - Explore and Events Discovery
# IS Business Analyst - Data Analyst
# Clerk, Voter Data Coordinator
# Business Intelligence Data Analyst - Healthline
# Business Intelligence Developer
# Artificial intelligence/cybersecurity reporter
# Data Scientist
# Data Scientist
# Data Scientist
# Machine Learning Engineer
# Registry Data Analyst
# Machine Learning Research Engineer II
# Business Data Analyst
# Actuarial Statistician
# Customer Data Architect
# Data scientist - Global Sales
# Head of Risk Data Science
# Data Scientist
# Business Intelligence Lead, Strategy & Planning
# Sr. Data Scientist
# 2020 PhD Data Scientist Internship - Policy, Research, & Economics (San Francisco)
# Senior Machine Learning Engineer
# Senior Solutions Architect (Data)
# Data Engineer, ETL
# Postdoctoral Fellow in Biological Data Science (Stanford/PICI)
# Data Engineer - Experimentation (XP) Team
# Sr. Data Scientist - Product Analytics
# Data Engineer
# Mgr, Data Reporting & Analytic - Business Management
# (Intern) Data Analytics Engineering
# Director Data Sciences Group
# Data Scientist
# Principal Software Engineer, Machine Learning
# Data Engineers - Hadoop
# Data Pipeline Engineer
# Senior Statistical Programmer
# Senior Manager, Collaboration and Data Management
# Sr Business Analyst - Process Improvement/Data Analytics
# Lead Clinical Data Abstractor
# Data Analyst (mid-level)
# Data Analyst - Consumer Experience
# Business & Data Analyst
# Research Data Analyst (6256U), Haas School of Business
# Sr Software Engineer - Machine Learning
# Engineering Manager, Data Infrastructure
# Senior Data Quality Lead
# Senior Data Pipeline Engineer
# Software Engineer, Customer Data Applications
# Data Analyst - HR
# Senior Software Engineer - Machine Learning
# Cost TCO Analyst - Data Center Construction
# Data Scientist
# Senior Statistical Programmer
# Product Manager - Data
# Senior Data Analyst
# Business Intelligence Analyst
# Solutions Engineer, Rev.ai
# Director, Data Science - Client Services
# Manager, Workday Data Conversion Lead
# Software Engineer - Data Infrastructure
# Senior Statistical Programmer
# Senior Director/Director Product Management, Analytics and Data Services - San Mateo, CA
# Sr. Clinical Data Manager
# Senior Data Scientist
# Lead Security Architect - Big Data
# Senior Manager, Data Science - NLP Solutions Team
# Lead Software Engineer, Data Analytics
# Data Software Engineer Intern
# Chief Software Engineer-Data Product Development
# Manager, Oracle Cloud Technical Data Conversion Lead
# Senior Data Scientist, Machine Learning
# Business Intelligence Engineer
# Software Engineer, Machine Learning Infrastructure
# Engineering Manager, Machine Learning Infrastructure
# Senior Data Scientist, Analytics
# Software Engineer, Data Infrastructure
# Machine Learning Engineer
# Machine Learning Researcher (NLP) - Cortex Applied Machine Learning
# Senior Machine Learning Engineer - Sensor Intelligence
# Data Scientist - Global Optimization
# Data Scientist
# GPU AI and Simulation Engineer
# Data Management and Occupancy Planner
# Performance Architect/Lead - BI Data Modelling
# Corporate Data Security Attorney
# Specialist: Intake Worker and Data Management
# Computational and Data Science Research Specialist (6104U), Haas School of Business
# Data Scientist, Google Customer Solutions
# Business Analyst, Data Governance
# Data Analyst
# Lead Business Intelligence (BI) Engineer
# Business Intelligence & Analytics Manager
# Data Scientist #5967
# Data Analyst, Summer Internship
# Data Analyst – University Graduate
# Data Analyst, YouTube Trust and Safety
# Solutions Data Engineer
# Manager, Data & Analysis
# Data Infrastructure Engineer
# Data Science Manager
# Data Analyst
# Data Analyst/Developer
# Staff Software Engineer, Machine Learning Infrastructure (SF)
# Lead Data Scientist
# Data Engineer
# Intern, Finance Data Science
# Data Scientist
# Senior Backend Developer For AI Enhanced Fashion Platform
# Data Engineer II
# Full Stack Engineer, AI Labs
# Staff Data Engineer
# AI Engineering Intern
# Senior Data Engineer
# Senior Data Engineer
# Sr. Staff Data Engineer #6005
# Senior Data Analyst
# Principal Data Scientist
# Director, Data Quality and Management (0675U), University Development & Alumni Relations
# Data Manager- Compliance & Audit
# Principal Clinical Data Manager, Clinical Data Management
# (Senior) Data Engineer, DevOps
# Sr Data Science Manager - Financial Products
# Senior Product Manager, Data Platform
# Project Controls Manager - Data Center Construction - San Francisco, California
# Senior Clinical Data Scientist-Contractor
# Sr. Engineering Manager (Big Data Platform)
# Senior Software Engineer- Core Technology Group (CTG) Data Engine
# Uber AI Residency Program 2020 [San Francisco and Toronto]
# Staff Data Scientist
# Business Intelligence Engineer
# Data Scientist
# Data Analyst, Trust and Safety
# Data Science and Machine Learning Engineering Lead
# Data Scientist Intern, SBG Small Business Group (MBA)
# Data Scientist Intern, SBG Small Business Group (PhD)
# Data Scientist
# Microbiome Data Scientist
# Technical Program Manager - Data Engineering and Integrations
# Data Scientist - Experimentation
# Geospatial Data Scientist
# Data Scientist - Pet Insight Project
# Data Scientist - Client Recommendations
# Sales Support - Data Entry
# Principal Machine Learning Scientist
# Data Exchange / Transfer Specialist
# Tableau Developer
# Data Project Manager (Contract)
# Data Scientist
# Lead Machine Learning Engineer, Entity Understanding
# Data Quality Scientist
# Staff Machine Learning Platform Engineer
# Data Engineer
# Senior Data Scientist, Conversations
# HMIS Data Program Manager
# Data Science Manager - Inventory Modeling and Forecasting
# Data Engineer
# Lead Data Architect
# Sr. Data Analyst Freight
# Data Scientist, Product Analytics - Ads
# Data Science Manager, SBG
# Data Science, Intern (Record Linking)
# Solutions Consultant, Cloud AI Technical Operations
# Data Engineer
# Machine Learning Engineer - Advisory – Manager
# Senior Business Intelligence Analyst
# Senior Data Scientist
# eDiscovery - Data Management Services, Consultant
# Senior Software Engineer, Machine Learning
# Public Policy Manager - Data
# Senior Data Engineer
# Data Science, Intern (Personalization)
# Data Analyst
# Associate Data Science Engineer
# Account Executive – AI/ML
# Sr. Big Data Architect / Product Architect
# Senior Analyst, Technology, Data and Information Management
# Lead Data Engineer
# HVAC (BMS) Controls and Data/Security Systems Installer
# Data Entry Sales Associate
# Lead Data Engineer
# Senior Data Engineer
# Data Engineer
# Data Engineer
# Marketing Data and Technology, Intern
# Senior Data Science Engineer
# Staff Software Engineer - Data Infrastructure
# Senior Data Analyst
# Data Engineering Tech Lead
# Senior Statistical Programmer Safety Biometrics
# Product Manager, Data
# Senior Data Engineer
# Data Product Manager
# Senior Big Data Engineer
# Data Engineering Intern
# Senior Data Engineer
# eDiscovery - Data Management Services, Senior Consultant
# Senior Clinical Data Manager
# Senior Staff Software Engineer, Machine Learning Infrastructure (SF)
# Data Science Engineer, Intern
# Senior Product Manager, Data Platform
# Manager, Applied ML/AI - Trust & Safety
# Backend Software Engineer (CO-OP/Data Lake)
# Construction Program Manager - Data Centers - San Francisco, California
# Senior Software Engineer, Data Science
# Senior Software Research Engineer - Uber AI
# Cost Manager / Quantity Surveyor - Data Center Construction - San Francisco, California
# Lead Software Engineer, Data Infrastructure
# Associate Director Cost Manager / Quantity Surveyor - Data Center Construction - San Francisco, California
# Data Scientist
# PhD Software Engineer Intern, Rideshare / Machine Learning (Summer 2020)
# Data Scientist - Analytics and Machine Learning
# Postdoctoral Rearcher - Statistical machine learning of neural time-series data
# Data Scientist
# Machine Learning Infrastructure Engineer
# Machine Learning Engineer
# Staff Machine Learning Engineer - Recommendations Platform
# Data Scientist
# HR Data Entry Specialist (4722C)
# Visualization and Data Engineer - Customer Success
# Senior Business Intelligence and Operations Analyst
# Data Scientist - Client Acquisitions, Visitor Experience
# English Speakers - Data Annotators
# Data Acquisition Specialist
# Data Capture Supervisor
# Business Intelligence Analyst
# Software Engineer, Machine Learning
# Director of Data Information Services
# Vice President, AI Strategy
# Director, Data Operations and Tools
# Data Analyst
# Data Analyst
# Principal Data Scientist
# Chinese Speakers - Data Annotators
# Axon Data Governance Consultant
# Data Center Technician
# Data Scientist - Insights & Modeling
# Sr. Business Intelligence Analyst
# Program and Data Assistant, Biology Scholars Program (4722C) - 1597 - 1597
# Financial Data Engineer
# Director, AI/ML Production Systems
# Data Analyst
# Lead Data Scientist
# Senior Director, Data Engineering and Infrastructure
# Sr Software Engineer (Machine Learning) - Maps - Personalization
# Enterprise Data Catalog Consultant
# Service Lead, Research Data Management Program (0657U) 1776 - 1776
# Senior Machine Learning Engineer
# Principal Data Engineer
# Lead Data Engineer
# Data Annotation Specialist
# Data Analyst
# Client Accelerators Data & Insights Specialist
# Data Scientist
# Sr Statistical Scientist, Biostatistics
# Business Intelligence Analyst
# Director, AI/ML Engineering
# Data Management Engineer
# Senior Data Engineer
# 2020 Summer Data Analyst Internship - Actuary
# Institutional Data and Research Analyst (6948U) - 1611 - 1611
# Engineering Manager, Privacy and Data Protection Engineering
# Big Data Hadoop Developer (Data Engineer)
# Senior IT BI Engineer
# Senior Data Engineer
# Director of Engineering -Data Platform
# Data Analyst Intern (Summer 2020)
# 2020 Summer Data Analyst Internship - Safety & Insurance
# Director of Engineering -Data Platform
# Sr. Business Intelligence Analyst - Web Analytics
# Clinical Data Manager
# Lead or Principal Data Scientist
# Senior Data Science Engineer
# Clinical Data Manager Contractor
# Enterprise Data Governance Program Manager
# Engineering Manager, Global Internet Data Collection
# AI Conversational Design & Implementation Lead (AI Consultant 2)
# Senior AI Program Manager
# Assoc. Director, R & D Information Systems, Data Scientist
# Staff Software Engineer, Cloud Data Plane & Proxy
# Manager, Data & Impact Measurement
# ML/AI Manager, Software Engineering
# Data Governance Automation Lead
# Axon Data Governance Consultant
# Data Intelligence, Strategy & Growth, U4B Sales Ops MBA Intern- Summer 2020
# Client and Market Growth Data & Insights Lead
# Data Systems Analyst 2 (7198U)
# Enterprise Data Catalog Consultant
# Data Center Security Installation Technician - Bay Area
# Staff Software Engineer, Data Analytics
# Senior Data Systems Analyst (0599U) - 1668
# Senior Product Manager, Data Platform
# Sr. Manager, Data Science Engineering
# Staff Software Development Engineer in Test, Data Plane
# Digital Marketing Data Analyst
# Senior Software Engineer, Data Platform - Data Factory
# Digital Communications Manager (7461U) Job 2595 - Division of Data Science & Information - 2595
# Senior/Principal Product Manager, Data Platform – San Mateo, CA
# Sr. Staff Software Development Engineer in Test, Data Engineering
# Specialist SA, Machine Learning/AI Services
# Data Scientist - Machine Learning
# Machine Learning Scientist
# Intern, Artificial Intelligence (AI) Research
# Intern, Design and Machine Learning
# Data Nerd
# Senior/Principal Data Engineer, Business Intelligence
# Data Scientist
# Vice President, Data
# Data Scientist - Intern
# Data Architect
# Machine Learning Engineer
# Lead Machine Learning Engineer
# Data Scientist
# Data Analyst Intern
# Staff Machine Learning Engineer - Core Algorithms
# AI Techlead
# Assistant Product Data Specialist
# Assistant Product Data Specialist
# Data Science - Product
# Senior Data Analyst
# Senior Data Scientist
# Data Engineer
# Scientist/Machine Learning Engineer, Applied Science
# Senior Data Analyst
# Data Analyst Quality I
# Intern, Statistical Programming
# Data Analyst
# Sr. Data Architect
# Director of Data Engineering
# Senior Data Engineer
# Sr. Data Engineer
# Principal Statistical Programmer
# Sr Data Engineer - Customer Engagement
# Senior Data Scientist
# Senior Data Architect
# Statistical Programmer II
# Sr. Principal Clinical Trial Statistician
# Data Science Manager
# Software Engineer, Data Persistence
# Senior Research Machine learning Eng, App Science Research
# Senior Data Engineer
# Sr Data Scientist, Tech Lead - Maps
# Environmental Data Science Postdoctoral Fellow
# Data Science Manager
# Data Science Intern (Summer 2020)
# Data Science Manager
# Product Manager - AI/ML
# Data Center Hardware & Network Engineer
# Software Engineer, Data Platform
# Senior/Staff Data Scientist, Analyst
# Consulting Data Analyst - SAS, SQL, Python, R
# Data/Software Engineer Returnship
# Data Engineer Intern - Summer 2020
# Paid Summer Intern - Undergraduate, Data Science
# Senior Data Science & Strategy Analyst
# Senior/Principal Statistical Programmer
# Paid Summer Intern - Graduate, Data Scientist
# Sr Manager Statistical Programming
# Sr. Manager Data Science - Head of Consumer Decision Science
# AI Product Manager
# Engineering Manager, Data Platform
# Software Engineer, Data Systems
# Senior AI Engineer
# Senior Security Engineer - Cloud & AI
# Leader, Marketing Data Science, Member and Engagement Products
# Senior Consulting Data Analyst - SAS, R, Python
# Senior Business Intelligence Analyst
# Senior / Lead Engineer, Machine Learning Backend
# Senior Software Engineer, Data Ocean Platform
# Consultant II, Project Coordination/Data Analyst Consultant (Associate Level)
# Senior Statistical Scientist/Associate Director, Biostatistics
# Leader, Marketing Data Science, Consumer Lending Products
# Senior Technical Product Manager, Data Products
# Senior Full-Stack Software Engineer, Data Platform
# Measurement Data Scientist (SF)
# Data Architect
# Strategic Negotiator, Data Center Acquisitions
# Data Scientist
# Head of Google Data Centers Business Systems
# Business Intelligence Analyst - New Mobility
# Data Analyst, Safety and Insurance
# Machine Learning Engineer
# 2020 Artificial Intelligence/Machine Learning Graduate Summer Intern
# Data Scientist
# Geospatial Data Scientist
# Data Analyst- San Francisco
# Data Analyst
# Data Scientist
# Data Science Analyst
# AI Architect
# Machine Learning (ML) Engineer- Core ML
# Data Center Network Architect
# Director of Data Analytics-IT
# Data Analyst, Ads Marketing
# Data Scientist
# Data Scientist - Marketplace
# Product Data Analyst
# Senior Data Scientist
# Senior Data Scientist, Talent Acquisition
# Lead Data Scientist - Underwriting Algorithms
# Big data Engineer
# Data Center Regional Contract Manager
# Data and Content Migration Developer (Java)
# Sr. Software Engineer, Machine Learning Infrastructure
# Data Science Internship - Summer 2020
# ...
# Senior Data Scientist
# Data Analytics Pipelines Section Manager
# Master Data Engineer - Card Technology
# Senior Data Analyst
# Senior Data Scientist
# Data Modeler, Senior
# Data Modeler - GEOINT Standards - Expert Level (1581)
# Intelligence Data Analyst, Senior
# Data Scientist TOP SECRET CLEARANCE REQUIRED
# Security - Senior Data Engineer
# Data Modeler - GEOINT Standards - Senior Level (1580)
# Data Scientist Senior/Expert TS/SCI
# Transplant Quality Data Specialist, Nurse Preferred
# Mid-Level Data Analyst
# Data Scientist- Senior Associate
# Federal - Data Analytics Consultant
# Data Analyst - Mid_ANG
# Data Center Account Executive - Civilian
# Big Data Architect
# Senior Data Engineer
# Data Scientist
# Senior Financial Data Analyst
# Data Analyst Mid
# Data Architect -- Rosslyn, VA
# Data Management Analyst / Digital Strategy / Research / Navy
# Senior Data Scientist
# Data Analytics Pipelines Section Manager
# Master Data Engineer - Card Technology
# Senior Data Analyst
# Senior Data Scientist
# Data Modeler, Senior
# Data Modeler - GEOINT Standards - Expert Level (1581)
# Intelligence Data Analyst, Senior
# Data Scientist TOP SECRET CLEARANCE REQUIRED
# Security - Senior Data Engineer
# Data Modeler - GEOINT Standards - Senior Level (1580)
# Data Scientist Senior/Expert TS/SCI
# Transplant Quality Data Specialist, Nurse Preferred
# Mid-Level Data Analyst
# Data Scientist- Senior Associate
# Federal - Data Analytics Consultant
# Data Analyst - Mid_ANG
# Data Center Account Executive - Civilian
# Big Data Architect
# Senior Data Engineer
# Data Scientist
# Senior Financial Data Analyst
# Data Analyst Mid
# Data Architect -- Rosslyn, VA
# Data Management Analyst / Digital Strategy / Research / Navy
# Senior Data Scientist
# Data Analytics Pipelines Section Manager
# Master Data Engineer - Card Technology
# Senior Data Analyst
# Senior Data Scientist
# Data Modeler, Senior
# Data Modeler - GEOINT Standards - Expert Level (1581)
# Intelligence Data Analyst, Senior
# Data Scientist TOP SECRET CLEARANCE REQUIRED
# Security - Senior Data Engineer
# Data Modeler - GEOINT Standards - Senior Level (1580)
# Data Scientist Senior/Expert TS/SCI
# Transplant Quality Data Specialist, Nurse Preferred
# Mid-Level Data Analyst
# Data Scientist- Senior Associate
# Federal - Data Analytics Consultant
# Data Analyst - Mid_ANG
# Data Center Account Executive - Civilian
# Big Data Architect
# Senior Data Engineer
# Data Scientist
# Senior Financial Data Analyst
# Data Analyst Mid
# Data Architect -- Rosslyn, VA
# Data Management Analyst / Digital Strategy / Research / Navy
# Senior Data Scientist
# Data Analytics Pipelines Section Manager
# Master Data Engineer - Card Technology
# Senior Data Analyst
# Senior Data Scientist
# Data Modeler, Senior
# Data Modeler - GEOINT Standards - Expert Level (1581)
# Intelligence Data Analyst, Senior
# Data Scientist TOP SECRET CLEARANCE REQUIRED
# Security - Senior Data Engineer
# Data Modeler - GEOINT Standards - Senior Level (1580)
# Data Scientist Senior/Expert TS/SCI
# Transplant Quality Data Specialist, Nurse Preferred
# Mid-Level Data Analyst
# Data Scientist- Senior Associate
# Federal - Data Analytics Consultant
# Data Analyst - Mid_ANG
# Data Center Account Executive - Civilian
# Big Data Architect
# Senior Data Engineer
# Data Scientist
# Senior Financial Data Analyst
# Data Analyst Mid
# Data Architect -- Rosslyn, VA
# Data Management Analyst / Digital Strategy / Research / Navy
# Senior Data Scientist
# Data Analytics Pipelines Section Manager
# Master Data Engineer - Card Technology
# Senior Data Analyst
# Senior Data Scientist
# Data Modeler, Senior
# Data Modeler - GEOINT Standards - Expert Level (1581)
# Intelligence Data Analyst, Senior
# Data Scientist TOP SECRET CLEARANCE REQUIRED
# Security - Senior Data Engineer
# Data Modeler - GEOINT Standards - Senior Level (1580)
# Data Scientist Senior/Expert TS/SCI
# Transplant Quality Data Specialist, Nurse Preferred
# Mid-Level Data Analyst
# Data Scientist- Senior Associate
# Federal - Data Analytics Consultant
# Data Analyst - Mid_ANG
# Data Center Account Executive - Civilian
# Big Data Architect
# Senior Data Engineer
# Data Scientist
# Senior Financial Data Analyst
# Data Analyst Mid
# Data Architect -- Rosslyn, VA
# Data Management Analyst / Digital Strategy / Research / Navy
# Senior Data Scientist
# Data Analytics Pipelines Section Manager
# Master Data Engineer - Card Technology
# Senior Data Analyst
# Senior Data Scientist
# Data Modeler, Senior
# Data Modeler - GEOINT Standards - Expert Level (1581)
# Intelligence Data Analyst, Senior
# Data Scientist TOP SECRET CLEARANCE REQUIRED
# Security - Senior Data Engineer
# Data Modeler - GEOINT Standards - Senior Level (1580)
# Data Scientist Senior/Expert TS/SCI
# Transplant Quality Data Specialist, Nurse Preferred
# Mid-Level Data Analyst
# Data Scientist- Senior Associate
# Federal - Data Analytics Consultant
# Data Analyst - Mid_ANG
# Data Center Account Executive - Civilian
# Big Data Architect
# Senior Data Engineer
# Data Scientist
# Senior Financial Data Analyst
# Data Analyst Mid
# Data Architect -- Rosslyn, VA
# Data Management Analyst / Digital Strategy / Research / Navy
# Senior Data Scientist
# Data Analytics Pipelines Section Manager
# Master Data Engineer - Card Technology
# Senior Data Analyst
# Senior Data Scientist
# Data Modeler, Senior
# Data Modeler - GEOINT Standards - Expert Level (1581)
# Data Governance Senior Analyst
# Data Coordinator
# Director - Data Science and Robotics Automation
# Sr. Data Scientist
# Vice President Data Science
# Senior Associate Data Science
# Data Scientist Manager
# Chase Reference Data Strategy Manager, VP
# Sr. Associate Data Scientist - Sales Science Strategy & Capabilities
# Data Center Operations Manager
# Data Center Manager
# Director - Data Science and Robotics Automation
# Vice President Data Science
# Data Center Technician (AWS GovCloud Region)
# Product Analyst, Master Data
# Senior Associate Data Science
# Data Scientist Manager
# Chase Reference Data Strategy Manager, VP
# Sr. Associate Data Scientist - Sales Science Strategy & Capabilities
# IS Epic Data Courier and Security Application Coordinator
# Supply Chain Data Analytics Specialist
# Enterprise Data Catalog (EDC) Consultant
# Senior Data Analyst
# IS Systems Analyst Sr - Business Intelligence
# PROFESSIONAL.Bus Intel and Data Visualization Lead
# Manager, Software Engineering (Data & Analytics)
# Senior Data Scientist - Ohio Only
# Bi-lingual Community Family Intervention Provider (Spanish)
# Research Statistician
# Fraud Data Analyst
# Data Solution Architect
# BI Architect
# Consultant - Business Intelligence - Dublin - OH
# Tableau Trainer
# Machine Learning /Artificial Intelligence - Product Analyst - Columbus, OH
# Machine Learning /Artificial Intelligence - Product Analyst - Columbus, OH
# GIMS Data Base Administrator
# Education Data Specialist
# Data Center Tech Intern
# Lab Assistant/Data Entry
# Tableau Developer on W2
# Cloud Data Engineer
# NHATS 2020 – Data Collector
# Sr Data Architect - Data Lake & Analytics - Nationwide Opportunities
# Director - Medical Master Data Technologies
# Commercial Banking –Executive Director - Data Science, Analytics & Insights
# CCB - Consumer Banking - Reporting & Data Analytics - Associate
# Master Data Management (MDM) Associate Manager
# Sr Analyst, Global Trade Compliance (Supply Chain Data Analytics)
# Pharmacy Technician II (Data Entry)
# Data Analytics Specialist
# Big Data
# Master Data Specialist
# Junior Data Coordinator
# Fast Data Collector- Soccer- Columbus, OH
# Data Analyst
# Data Analyst
# Senior Data Analyst
# Big Data Architecture Lead
# Sr. Analyst Data Analytics Software Engineer
# Data Scientist (Analytics)
# Master Data Specialist
# Big data lead /sr .developer
# Data Analytics Consultant
# Data Architect - Data Lake & Analytics - Nationwide Opportunities
# Advisor, Data Analytics - Strategic Partnership Management
# Java Big Data Developer
# Data Governance Consultant
# Sr Data Architect - Data Warehouse & MPP - Nationwide Opportunities
# Entry Level Customer Service and Data Entry
# Java Engineer – Data Platform
# SAP BODS/Data Services Developer– Manager (Technology)
# Senior Java Engineer – Data Platform
# Data Governance and Metadata Consultant
# Machine Learning & AI Internship | Winter and Spring Programs
# NLP Data Scientist
# Data Entry Clerk
# Data Scientist
# Clin Res Data Coordinator - RI Gene Simmons
# Data Analyst
# Data Coordinator
# Data Center Technician
# BMT Coordinator- Data
# SQL Data Developer
# Big Data (Lead Developer)
# Data Entry Clerk and Quality Control 10am to 6pm
# Digital Transactional Data Owner
# Clerk, Data Processing
# Marketing Data Specialist II
# IS Data Center Analyst II
# Central Intake Data Coordinator
# Data Architect Sr Associate
# Digital Transactional Data Owner
# Sr Data Engineer- Data Warehouse (ETL)
# Project Manager & Data Analyst
# Data Architect Sr Associate
# Data Center Technician IC1
# Project Manager -Data Center
# Manager- BI Reporting
# Data Center Support Technician
# Data Systems Assistant Administrator
# Data Warehouse Data Modeler Specialist
# Data Scientist, Insurance
# Sr Business Data Anlst
# Master Data and Metadata Analyst
# Data Entry/Document Imaging
# Data Entry Specialist
# Security Operations and Data Analytics Engineer
# Infrastructure Business Data Analyst
# Analyst Data - YRS R5165
# CCB - Data Analytics, Home Lending External Reporting - Associate
# Warehouse Audit/Data Entry
# Data Warehouse ETL developer (BI Technologies)
# Consultant, Business Analysis, (Pharma Data and Analytics)
# Data Intelligence Solutions Architect
# SAP Data Steward Business Partner
# Consultant, Business Intelligence
# Sr ETL BI Tester
# Business Intelligence Senior Architect - Profitability
# Sr Data Analytics Specialist
# Legal - Assistant General Counsel - Responsible Banking, Data & Privacy - VP
# Machine Learning Engineering Lead
# Data Scientist Internship
# Data Analytics Analyst
# CCB - Quantitative Modeling/Data Science - Vice President
# Data Analyst, Operational Analytics
# Data Steward
# Claims Data Analyst
# Machine Learning Engineering Lead
# Commercial Data & Insights Analyst
# Program Manager- Corporate Data & Analytics
# Data Project Manager - Junior
# Chase Reference Data Management Strategy Senior Associate
# Central Intake Data Coordinator
# HR Chief Data & Analytics Office - Associate, Data Management Data Analyst
# Senior Data Sales Specialist
# Senior Data Sales Specialist
# Chase Reference Data Management Strategy Senior Associate
# Consultant, People Analytics (Senior Data Engineer)
# Cloud Enablement, Manager – Data Delivery (Azure)
# Cloud Enablement, Manager – Data Delivery (GCP)
# Cloud Enablement, Senior Consultant – Data Delivery (Azure)
# Cloud Enablement, Senior Consultant – Data Delivery (GCP)
# Cloud Enablement, Senior Consultant – Data Delivery (AWS)
# Experienced Data Cabling Technician
# Consumer & Community Banking - Control Management - Control Manager - Program - Automated Testing - Data Support - Vice President
# Business Intelligence & Data Visualization Lead
# Customer Service and Data Entry Clerk
# Director, Data and Insights
# EDI Master Data Specialist
# Advisor, Data Analytics
# DATA ARCHITECT
# Laboratory Technician (Lab Analysis Administration and Data Entry)
# Specialist, Data Science
# Senior Data Analyst
# ETL/Data Warehouse Developer
# Consultant, Logistics, Business Intelligence
# Data Warehouse Manager
# LEAD BUSINESS INTELLIGENCE DEVELOPER
# Sr. Data Engineer
# Senior Advisor, Data Analytics, (Lead, Data & Analytics)
# Full Stack Java (+ big data)
# DATA ENGINEER II
# Big Data Hadoop Engineer
# Manager, Software Engineering (Pharma Data & Analytics)
# Senior Data Systems Architect
# Cybersecurity Data Protection Architect Expert
# Workday- Certified Data Assoc Mgr
# Data Center Operator
# Data Scientist/Modeler
# Associate Data Scientist
# Data Developer
# Business Systems Data Analyst
# Sr. Data Analyst
# Sr. Consultant, Data Analytics
# Human Resources HCM Data Analyst
# Customer Data Domain-Data Architect Lead
# Customer Data Domain-Data Architect Lead
# Business Intelligence Manager
# Data Analyst - Population Health
# Facilities Operations Manager, Global Data Centers
# Data Scientist III
# Business Intelligence Developer
# Data Analyst - CMDB
# Developer Advocate, AI API
# BI/ ETL Developer
# Data Center Security Manager
# Senior Specialist, Supplier Data Analysis
# Data Visualization UX Designer
# Data Scientist/Engineer
# Project Manager -Data Center
# CCB Treasury - Data Engineer - Vice President
# Java Machine Learning Software Engineering Lead
# Consultant, Business Data Management (Senior Data Engineer)
# Sr Data Steward - Customer Information Management Marketing
# Specialist, IT Data & Analytics (Data Solutions Analyst)
# Junior Data Warehouse Quality Analyst
# Consultant, Business Intelligence (Speech Analytics)
# Senior Analyst, Business Intelligence
# SQL Data Analyst
# Data Engineer
# Software Data Architect
# Enterprise Applications Data Owner
# Consultant, Data Governance + Dublin, OH
# Manager, Data Analytics + Dublin, OH
# Senior Engineer, Software Engineering (Technical Lead, Data & Analytics)
# Machine Learning Engineer
# Business Intelligence Architect
# Business Intelligence Developer/Analyst
# BI Claims Adjuster
# Data Protection Analyst
# Axon Data Governance Consultant
# Enterprise Data Catalog Consultant
# Business Intelligence R & D Internship
# Analyst, Compensation - Data Management & Analytics
# Big Data Site Reliability Engineer
# Data Governance Automation Lead
# Advisor, Data Analytics + Dublin, OH
# Coding & Data Services Coordinator- Mount Carmel Medical Group- Corporate Service Center
# Advisor, Data Analytics (Data Governance)
# Data Scientist
# Machine Learning Engineer
# Data Scientist
# Senior Data Scientist
# Big Data Engineer
# Data Science Manager
# Sr. Data Analyst, Global Audit
# Cyber Security Data Protection Business System Analyst 2
# Software Engineer - Big Data
# Big Data Engineer (Hadoop/Java/Python)
# Software Engineer - Big Data
# Program Manager, Data Center Environmental Health and Safety
# Data Center Technician
# Plant Engineer, Data Center Operations
# Data Center Facilities Technician
# Data Analyst - Promise 2020
# Sr. BI & Analytics Developer
# Abbott Nutrition Data Science Internship
# Senior Data Engineer (Data ELT/ETL Engineer)
# Information Security and Data Protection Analyst
# Sr QA Data Engineer
# Master Data Management, Senior Consultant - Data Delivery (Informatica MDM/360)
# Strategic Account Executive - Cloud Data Integration Leader
# Customer Facing Data Scientist
# Data Analytics Specialist
# Advisor, Data Analytics - People Analytics & Insights Team
# Data Modeler
# Specialist, Data Engineering
# Sr. Data Scientist, Advanced Analytics
# SAP Ariba Data Consultant
# SAP IBP Data Consultant
# Senior Software Engineer / Machine Learning
# SAP Product Lifecycle Management Data Consultant
# Sr. Data Center Delivery Engineer
# Administrative Assistant, Data Center Campus
# Director of Enterprise BI and Reporting
# Associate Data Scientist*
# Data Designer
# Data Center Project Engineer (Critical Infrastructure)
# Login Technician (Sample Receiving / Data Entry)
# Business Intelligence Senior Analyst
# Manager, Healthcare Analytics - HEDIS Data Analytics
# Data Scientist
# Data Center Specialist
# Director, Master Data & Governance
# Data Center Capacity Engineer
# CCB - Quantitative Modeling/Data Science Associate
# Hadoop Administrator-Big Data Admin
# Intermediate BI Developer - Epic Operational Reporting
# Associate BI Developer - Epic Clinical Reporting
# Low Voltage Voice and Data Technician
# Voice and Data Technician
# Data Center Technician
# Cloud Architect/Data Engineer
# Summer 2020 Internship Program - Data Science
# Intermediate BI Developer - Epic Clinical Reporting
# Voice/Data Wiring Cable Installer
# Data Cable Technician
# Voice/Data Wiring Cable Technician
# Senior Consultant, Advanced Analytics (Sr. Cloud Data Engineer- AAA)
# Data Resource Specialist - PN 20015095
# Junior BI/ETL Developer
# Project Manager- Data Center
# Data Engineering Manager
# Project Management Analyst (Data Analytics/Qlikview)
# Sustaining Engineer – Data Platform
# Genetic Data Analyst
# Data Security, Privacy & Governance Manager
# Intern- Data Scientist
# Data Center Site Manager
# Business Analyst - Business Intelligence
# Lead Data Center- Sales Solution Specialist
# AI Researcher I Deep Reinforcement Learning
# Data & Analytics Manager (IT Manager 1)
# Big Data with Scala
# Data Scientist/Solution Architect
# Big Data Consultant
# "Java/Hadoop Developer" OR "Big Data Engineer"
# Data Analyst Lead- Columbus, OH (LOCAL CANDIDATES ONLY)

# %%
# saving the data-jobs data in a csv file

data_jobs_df.to_csv('../data/all_data_jobs.csv', index=False)

# %% [markdown]
# ### Scraping Experience Data for the Job Postings

# %%
# getting the list of URLs for data jobs extracted from the job portal to be used in all scraping functions

url_list = data_jobs_df['url'].tolist()

# %%
# function that uses web scraping to get minimum experience requirement for data job postings

def get_years_of_experience(url_list):
    
    for i in url_list:
      
        try:
            res = requests.get(i)
            res.raise_for_status()
            Soup = bs4.BeautifulSoup(res.text, 'html.parser')
            item = Soup.select('#jobDescriptionText')
            item = str(item[0])
            item_clean = re.findall(r'(?:(\d+)(?=.*years?)(?=.*experience))|(?:experience.*(\d+).*\+years?)|(?:(\d+\+)(?=.*years?)(?=.*experience))', item)[0]
            item_clean = list(filter(None, item_clean))[0]   
            exp_url.append(i)
            exp_years.append(item_clean)

        except Exception:
            pass

# %%
exp_url = []
exp_years = []

# calling the function to get experience data

get_years_of_experience(url_list)

# %%
# creating a dataframe for minimum experience data

exp_years_df = pd.DataFrame({'url': exp_url,
                             'exp': exp_years
                        })

# further cleaning - excluding any invalid experience 'number of year' returned as a result of scraping if it is > 15
exp_years_df['exp'] = pd.to_numeric(exp_years_df['exp'])
exp_years_df = exp_years_df[exp_years_df['exp'] <= 15].reset_index()

exp_years_df.head(3)
# Out:
#    index                                                url  exp
# 0      0  http://www.indeed.com/viewjob?jk=389c5707bd0ad...    3
# 1      1  http://www.indeed.com/viewjob?jk=0df9dac32fbac...    3
# 2      2  http://www.indeed.com/viewjob?jk=385998e9d4244...    2

# %%
exp_years_df.head(3)

# %%
# saving minimum experience data in a csv file

exp_years_df.to_csv('../data/experience_data.csv', index=False)

# %% [markdown]
# ### Scraping Company Rating Data

# %%
# function that uses web scraping to get company rating and review count 

def get_company_reviews(url_list):
    
    for i in url_list:

        try:
            res = requests.get(i)
            res.raise_for_status()
            Soup = bs4.BeautifulSoup(res.text, 'html.parser')
            rating = Soup.select('.icl-Ratings-starsCountWrapper')
            rating = str(rating[-1])    
            rating = re.findall("[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?", rating)

            cmp_rating_url.append(i)
            cmp_rating.append(float(rating[0]))
            cmp_review_count.append(float(rating[-1]))            
      
        except Exception:
            pass

# %%
# calling the function to get company ratings 

cmp_rating_url = []
cmp_rating = []
cmp_review_count = []

get_company_reviews(url_list)

# %%
# creating a dataframe for company ratings

comp_rating_df = pd.DataFrame({'url': cmp_rating_url,
                               'rating': cmp_rating
                        })
comp_rating_df.head(3)
# Out:
#                                                  url  rating
# 0  http://www.indeed.com/viewjob?jk=389c5707bd0ad...     3.6
# 1  http://www.indeed.com/viewjob?jk=0df9dac32fbac...     3.8
# 2  http://www.indeed.com/viewjob?jk=385998e9d4244...     3.1

# %%
# saving company ratings data in a csv file

comp_rating_df.to_csv('../data/company_ratings_data.csv', index=False)

# %% [markdown]
# ### Scraping the Salary Data

# %%
# function that uses web scraping to get data job salaries  
 
def get_sal(url_list):
    
    for i in url_list:
         
        try:
            response = requests.get(i)
            response.raise_for_status()
            soup = bs4.BeautifulSoup(response.text, 'html.parser')
            salary = str(soup.select('div.jobsearch-JobMetadataHeader-item > span'))
            tag_re = re.compile(r'<[^>]+>|')
            salary = tag_re.sub('', salary)
            salary = salary[1:-1]
            salary = salary.replace('$', '')
            salary = salary.replace(',', '')
            if (not salary == '') and (contains_digits(salary)): 
                sal_url_list.append(i)
                sal_list.append(salary)
        except Exception:
            pass

# %%
def contains_digits(s):
    return any(char.isdigit() for char in s)

# %%
sal_list = []
sal_url_list = []

# calling the function to get salaries for the data jobs
get_sal(url_list)

# %%
# creating a dataframe of data job salaries

salary_df = pd.DataFrame({'url': sal_url_list,
                          'sal': sal_list
                        })

# %%
# function to clean the salary data further

def clean_sal_data(sal):
         
    if 'Part-time' in sal:
        sal = sal.replace('Part-time', '')
        
    if 'Contract' in sal:
        sal = sal.replace('Contract', '')  
        
    if 'Full-time Temporary' in sal:
        sal = sal.replace('Full-time Temporary', '') 
    
    if 'Full-time Temporary Contract' in sal:
        sal = sal.replace('Full-time Temporary Contract', '')
                          
    if 'Full-time Internship' in sal:
        sal = sal.replace('Full-time Internship', '')
                          
    if 'Temporary' in sal:
        sal = sal.replace('Temporary', '')
        
    if 'Full-time' in sal:
        sal = sal.replace('Full-time', '')
                            
    return sal


# Alternate way of writing this function is by using the below RegEx string   

#         tag_re = re.compile(r'\b\w*(?i)(part-time|Contract|Full-time Temporary|Full-time Temporary Contract|Full-time Internship|Temporary|Full-time)\w*\b')
#         salary = re.sub(tag_re, "", sal)

# %%
# cleaning salary data

salary_df['sal'] = salary_df['sal'].apply(clean_sal_data).str.rstrip('-')

# %%
# function to calculate minimum salary

def get_min_sal(salary):
    
    salary = salary.split(" - ")
    
    # getting mins  
    sal_min = re.findall("[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?", salary[0])[-1]
   
    # cadence
    cadence = ''.join(filter(lambda x: x.isalpha(), salary[-1]))

    sal_dict.update({
        'min': float(sal_min),
        'cadence': cadence
    }) 

    # logic to take salaries to year digits
    
    if sal_dict['cadence'] == 'aday':
        sal_dict['min'] = float(sal_min) * 260

    elif sal_dict['cadence'] == 'amonth':
        sal_dict['min'] = float(sal_min) * 12
                  
    elif sal_dict['cadence'] == 'aweek':
        sal_dict['min'] = float(sal_min) * 52 
            
    elif sal_dict['cadence'] == 'anhour':
        sal_dict['min'] = float(sal_min) * 2080
        
    
        
    return sal_dict['min']

# %%
# function to calculate maximum salary

def get_max_sal(salary):
    
    salary = salary.split(" - ")
    
    # getting maxs
    sal_max = re.findall("[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?", salary[-1])[-1]

    # cadence
    cadence = ''.join(filter(lambda x: x.isalpha(), salary[-1]))

    sal_dict.update({
        'max': float(sal_max),
        'cadence': cadence
    }) 

    # logic to take salaries to year digits
    
    if sal_dict['cadence'] == 'aday':
        sal_dict['max'] = float(sal_max) * 260

    elif sal_dict['cadence'] == 'amonth':
        sal_dict['max'] = float(sal_max) * 12       
        
    elif sal_dict['cadence'] == 'aweek':        
        sal_dict['max'] = float(sal_max) * 52 
                
    elif sal_dict['cadence'] == 'anhour':       
        sal_dict['max'] = float(sal_max) * 2080
        
    return  sal_dict['max']

# %%
# splitting items into a dictionary

sal_dict = {'min': 0,
            'max': 0,
            'cadence': ''
}

salary_df['annual_min_salary'] =  salary_df['sal'].apply(get_min_sal)
salary_df['annual_max_salary'] =  salary_df['sal'].apply(get_max_sal)

# %%
sal_df = salary_df[['url', 'annual_min_salary', 'annual_max_salary']]
sal_df.tail(2)
# Out:
#                                                    url  annual_min_salary  \
# 547  http://www.indeed.com/viewjob?jk=ed09008b730b6...            80017.6
# 548  http://www.indeed.com/viewjob?jk=1373bdf4a40b4...            80017.6
#
#      annual_max_salary
# 547           114379.2
# 548            80017.6

# %%
# saving the salary data in a csv file

sal_df.to_csv('../data/sal_data.csv', index=False)
